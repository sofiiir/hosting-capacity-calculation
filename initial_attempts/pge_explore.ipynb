# %%
import geopandas as gpd
import pandas as pd

# set option to see all data frame columns
pd.set_option('display.max_columns', None)

# %%
networked = gpd.read_file("../../../../../../capstone/electrigrid/data/utilities/pge_shapefiles/NetworkedSecondaryBuffer.shp")

# %%
networked.head()
# Out:
#                       Label  Publish  Last_Updat    SHAPE_Leng    SHAPE_Area  \
# 0  NetworkedSecondaryBuffer        1  2025-06-02  14446.569570  7.756554e+06
# 1  NetworkedSecondaryBuffer        1  2025-06-02  11698.186321  4.206894e+06
#
#                                             geometry
# 0  POLYGON ((553726.963 4183158.069, 553736.930 4...
# 1  POLYGON ((563010.555 4183284.528, 562997.697 4...

# %%
ed_sub = gpd.read_file("../../../../../../capstone/electrigrid/data/utilities/pge_shapefiles/EDSubstations.shp")

# %%
ed_sub.head()
# Out:
#           Substation Substati_1 Voltage_kV  NUMBANKS REDACTED UNGROUNDED  \
# 0             LAMONT      25391         12         2      Yes       None
# 1  POTTER VALLEY P H      04228         12         3       No       None
# 2            HIGHWAY      04265         12         2       No       None
# 3          KING CITY      18203         12         3       No       None
# 4        BELLE HAVEN      02402       4.16         5      Yes       None
#
#         Division  Existing_D  Queued_DG  Total_DG  Publish  Last_Updat  \
# 0           Kern       18400      28060     46460        1  2025-06-02
# 1       Humboldt         540         90       630        1  2025-06-02
# 2      North Bay       12855      15529     28384        1  2025-11-20
# 3  Central Coast        2628       2835      5463        1  2025-11-18
# 4      Peninsula       17400       4760     22160        1  2025-06-02
#
#                          geometry
# 0  POINT (876359.283 3913857.542)
# ...

# %%
df_sub = gpd.read_file("../../../../../../capstone/electrigrid/data/utilities/pge_shapefiles/DFSubstationArea___PeakFacilityLoadingPercent.shp")

# %%
df_sub.head()
# Out:
#   substation             gnaneedid   division          gnafacilit  \
# 0      02402  GNA_0240201_Capacity  Peninsula  BELLE HAVEN BANK 1
# 1      02402  GNA_0240202_Capacity  Peninsula  BELLE HAVEN BANK 2
# 2      02402  GNA_0240203_Capacity  Peninsula  BELLE HAVEN BANK 3
# 3      02402  GNA_0240204_Capacity  Peninsula  BELLE HAVEN BANK 4
# 4      02402  GNA_0240205_Capacity  Peninsula  BELLE HAVEN BANK 5
#
#              bankname   substati_1 facilityty  facilityra  facilitylo  \
# 0  BELLE HAVEN BANK 1  BELLE HAVEN       BANK        7.05        6.52
# 1  BELLE HAVEN BANK 2  BELLE HAVEN       BANK        7.05        9.14
# 2  BELLE HAVEN BANK 3  BELLE HAVEN       BANK       15.84       17.34
# 3  BELLE HAVEN BANK 4  BELLE HAVEN       BANK       10.40        9.59
# 4  BELLE HAVEN BANK 5  BELLE HAVEN       BANK       29.69       25.06
#
#    facility_1  facility_2  facility_3  facility_4  peakfacili idnumber  \
# 0        6.49        6.51        6.64        6.85       97.11  0240201
# ...

# %%
igp = gpd.read_file("../../../../../../capstone/electrigrid/data/utilities/pge_shapefiles/igp_tline.shp")

# %%
igp.head()
# Out:
#    OBJECTID                                         PROJECT_NA   RATING   PGE  \
# 0         1            Rio Oso 230/115 kV Transformer Upgrades  230/115  2017
# 1         2              Round Mountain 500 kV Dynamic Support      500  2022
# 2         3  Contra Costa PP 230 kV Line Terminals Reconfig...      230  2023
# 3         4  Contra Costa PP 230 kV Line Terminals Reconfig...      230  2023
# 4         5  Contra Costa PP 230 kV Line Terminals Reconfig...      230  2023
#
#   CAISO CPUC   Approval    CONSTRUCTI Projected_  publish      Last_Updat  \
# 0  2007  N/A  PGE/CAISO  Construction   May-2025        1  20250415232159
# 1  2019  N/A  PGE/CAISO  Construction   Jun-2025        1  20250415232246
# 2  2022  N/A  PGE/CAISO   Engineering   Sep-2025        1  20250415232246
# 3  2022  N/A  PGE/CAISO   Engineering   Sep-2025        1  20250415232246
# 4  2022  N/A  PGE/CAISO   Engineering   Sep-2025        1  20250415232246
#
# ...

# %%
gna_sub= gpd.read_file("../../../../../../capstone/electrigrid/data/utilities/pge_shapefiles/GNASubstationArea__PeakFacilityDeficiencyPercent.shp")

# %%
gna_sub.head()
# Out:
#    division substation             gnaneedid facilityid        gnafacilit  \
# 0    Diablo      01202  GNA_0120201_Capacity    0120201    CLAYTON BANK 1
# 1    Diablo      01202  GNA_0120202_Capacity    0120202    CLAYTON BANK 2
# 2    Diablo      01202  GNA_0120203_Capacity    0120203    CLAYTON BANK 3
# 3    Diablo      01202  GNA_0120205_Capacity    0120205    CLAYTON BANK 5
# 4  East Bay      01204  GNA_0120403_Capacity    0120403  OAKLAND D BANK 3
#
#            bankname substati_1 facilityty primarydri distributi anticipate  \
# 0    CLAYTON BANK 1    CLAYTON       BANK       None       None       None
# 1    CLAYTON BANK 2    CLAYTON       BANK       None       None       None
# 2    CLAYTON BANK 3    CLAYTON       BANK       None       None       None
# 3    CLAYTON BANK 5    CLAYTON       BANK       None       None       None
# 4  OAKLAND D BANK 3  OAKLAND D       BANK       None       None       None
#
# ...

# %%
transmission = gpd.read_file("../../../../../../capstone/electrigrid/data/utilities/pge_shapefiles/TransmissionLines.shp")

# %%
transmission.head()
# Out:
#                          TLINE_NAME  RATEDKV SAP_FUNC_L  Publish  Last_Updat  \
# 0                         ELLIS TAP      115   ETL.4021        1  2025-06-02
# 1           PINE FLAT PH TAP (CDWR)      230   ETL.4821        1  2025-06-02
# 2              CHRISTIE-WILLOW PASS       60   ETL.6370        1  2025-06-02
# 3                        MIDSET TAP      115   ETL.1581        1  2025-06-02
# 4  PITTSBURG-DELTA ENERGY CENTER #2      230   ETL.3315        1  2025-06-02
#
#      SHAPE_Leng                                           geometry
# 0    264.492667  LINESTRING (627814.093 4176121.829, 627812.880...
# 1   1280.008073  LINESTRING (827593.490 4082587.267, 827454.596...
# 2  25586.274812  LINESTRING (569473.790 4206455.380, 569460.010...
# 3   1166.071797  LINESTRING (812224.925 3898824.642, 812226.774...
# 4   2116.634057  LINESTRING (599266.874 4208990.901, 599268.380...

# %%
df_circ = gpd.read_file("../../../../../../capstone/electrigrid/data/utilities/pge_shapefiles/DFCircuitsView.shp")

# %%
df_circ.head()
# Out:
#   substation               gnaneedid  division      gnafacilit  \
# 0      12041  GNA_012041102_Capacity  East Bay  OAKLAND D 1102
# 1      01201  GNA_012011101_Capacity  East Bay  OAKLAND C 1101
# 2      01201  GNA_012011102_Capacity  East Bay  OAKLAND C 1102
# 3      01201  GNA_012011103_Capacity  East Bay  OAKLAND C 1103
# 4      01201  GNA_012011104_Capacity  East Bay  OAKLAND C 1104
#
#                        bankname substati_1  facilityra   idnumber  last_updat  \
# 0              OAKLAND D BANK 5  OAKLAND D        7.48   12041102  2025-08-29
# 1  NETWORK GROUP OAKLAND C 1251  OAKLAND C        9.14  012011101  2025-08-29
# 2  NETWORK GROUP OAKLAND C 1251  OAKLAND C       10.27  012011102  2025-08-29
# 3  NETWORK GROUP OAKLAND C 1251  OAKLAND C        9.14  012011103  2025-08-29
# 4  NETWORK GROUP OAKLAND C 1251  OAKLAND C        9.14  012011104  2025-08-29
#
#   facilityty  facilitylo  facility_1  facility_2  facility_3  facility_4  \
# ...

# %%
feeder_load = gpd.read_file("../../../../../../capstone/electrigrid/data/utilities/pge_shapefiles/FeederLoadProfile.shp")

# %%
feeder_load.head()
# Out:
#    OBJECTID   FeederID MonthHour  division     Low     High  Publish  \
# 0         1   12232107     12_10   Mission  8168.0  11718.0        1
# 1         2  163451701     05_02  Stockton  1418.0   1576.0        1
# 2         3  163121103     10_23  Stockton  1214.0   2134.0        1
# 3         4  253391104     02_01      Kern  1947.0   2199.0        1
# 4         5   12041134     12_06  East Bay  2193.0   2802.0        1
#
#        Last_Updat geometry
# 0  20250602010025     None
# 1  20251121081319     None
# 2  20251121081258     None
# 3  20251121081319     None
# 4  20251121081320     None

# %%
known_load = gpd.read_file("../../../../../../capstone/electrigrid/data/utilities/pge_shapefiles/KnownLoad.shp")

# %%
known_load.head()
# Out:
#    Circuitid                 CircuitNam Unique_Ide         Type  \
# 0  083701101                 STONE 1101   35510745  Residential
# 1  013501101                JARVIS 1101   35612424  Residential
# 2  082952113              EDENVALE 2113   35615107  Residential
# 3  253372104           BAKERSFIELD 2104   35597920  Residential
# 4  022331108  HUNTERS POINT (SF P) 1108   35461203  Residential
#
#             Category               SUBNAME IEPR_Statu Expected_L  \
# 0  Home Construction                 STONE        N/A         CC
# 1  Home Construction                JARVIS        N/A         CC
# 2  Home Construction              EDENVALE        N/A         CC
# 3  Home Construction           BAKERSFIELD        N/A         CC
# 4  Home Construction  SF P (HUNTERS POINT)        N/A         CC
#
#               Status Completed_  publish  Last_Updat    SHAPE_Leng  \
# 0       Monitor Load         No        1  2025-09-12  40036.450209
# ...

# %%
cust = pd.read_csv("../../../../../../capstone/electrigrid/data/utilities/pge_customer/PGE_2025_Q4_ElectricUsageByZip.csv")

# %%
cust.head()
# Out:
#    ZIPCODE  MONTH  YEAR       CUSTOMERCLASS COMBINED TOTALCUSTOMERS TOTALKWH  \
# 0    93101     10  2025  Elec- Agricultural        Y              0        0
# 1    93101     11  2025  Elec- Agricultural        Y              0        0
# 2    93101     12  2025  Elec- Agricultural        Y              0        0
# 3    93110     10  2025  Elec- Agricultural        Y              0        0
# 4    93110     11  2025  Elec- Agricultural        Y              0        0
#
#   AVERAGEKWH
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
cust_q3 = pd.read_csv("../../../../../../capstone/electrigrid/data/utilities/pge_customer/PGE_2025_Q3_ElectricUsageByZip.csv")

# %%
cust_q3.head()
# Out:
#    ZIPCODE  MONTH  YEAR       CUSTOMERCLASS COMBINED TOTALCUSTOMERS TOTALKWH  \
# 0    93101      7  2025  Elec- Agricultural        Y              0        0
# 1    93101      8  2025  Elec- Agricultural        Y              0        0
# 2    93101      9  2025  Elec- Agricultural        Y              0        0
# 3    93110      7  2025  Elec- Agricultural        Y              0        0
# 4    93110      8  2025  Elec- Agricultural        Y              0        0
#
#   AVERAGEKWH
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
feeder = gpd.read_file("../../../../../../capstone/electrigrid/data/utilities/pge_shapefiles/FeederDetail.shp")

# %%
feeder.head()
# Out:
#   Substation   FeederID      Feeder_Nam Nominal_Vo Load_Profi  ResCust  \
# 0  TIDEWATER  014652109  TIDEWATER 2109       21kV         No     5234
# 1    HIGHWAY  042651101    HIGHWAY 1101       12kV         No     3895
# 2  DEL MONTE  182222104  DEL MONTE 2104       21kV         No     3932
# 3  BERESFORD  024040404  BERESFORD 0404     4.16kV         No     1142
# 4   PURISIMA  182971101   PURISIMA 1101       12kV         No     2154
#
#    ComCust  IndCust  AgrCust  OthCust  Existing_D  Queued_DG  Total_DG  \
# 0      358       59        0       24        6930        330      7260
# 1      134       18        2        0        9055       9583     18638
# 2      757      221       10        0        9150      10999     20149
# 3       57        6        0        5         660         60       720
# 4      161       27       69        0        3182       3313      6495
#
#         Division  VOLTNUM  Publish  Last_Updat     SHAPE_Leng  \
# ...

# %%
feeder['total'] = feeder['ResCust'] + feeder['ComCust'] + feeder['IndCust'] + feeder['AgrCust'] + feeder['OthCust']

# %%
feeder['perc_res'] = feeder['ResCust'] / feeder['total'] * 100

# %%
feeder['perc_cust'] = feeder['ComCust'] / feeder['total'] * 100

# %%
feeder['perc_ind'] = feeder['IndCust'] / feeder['total'] * 100

# %%
feeder['perc_agr'] = feeder['AgrCust'] / feeder['total'] * 100

# %%
feeder['perc_oth'] = feeder['OthCust'] / feeder['total'] * 100

# %%
feeder.head()
# Out:
#   Substation   FeederID      Feeder_Nam Nominal_Vo Load_Profi  ResCust  \
# 0  TIDEWATER  014652109  TIDEWATER 2109       21kV         No     5234
# 1    HIGHWAY  042651101    HIGHWAY 1101       12kV         No     3895
# 2  DEL MONTE  182222104  DEL MONTE 2104       21kV         No     3932
# 3  BERESFORD  024040404  BERESFORD 0404     4.16kV         No     1142
# 4   PURISIMA  182971101   PURISIMA 1101       12kV         No     2154
#
#    ComCust  IndCust  AgrCust  OthCust  Existing_D  Queued_DG  Total_DG  \
# 0      358       59        0       24        6930        330      7260
# 1      134       18        2        0        9055       9583     18638
# 2      757      221       10        0        9150      10999     20149
# 3       57        6        0        5         660         60       720
# 4      161       27       69        0        3182       3313      6495
#
#         Division  VOLTNUM  Publish  Last_Updat     SHAPE_Leng  \
# ...
